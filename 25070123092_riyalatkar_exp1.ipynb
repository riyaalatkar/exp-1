# %%
#PRN 25070123092
#Riya Latkar

#defining the variables
x= "apple"
y= "orange"
z= "banana"
# or you can write it as
a,b,c= "apple","orange","banana"
print (x)
print (a)
print (y)
print (b)
print (z)
print (c)

print(x,y,z,a,b,c,sep="\n")
# Out:
# apple
# apple
# orange
# orange
# banana
# banana
# apple
# orange
# banana
# apple
# orange
# banana

# %%
#printing the different datatypes

p=2 # int
q=2.5 # float
r='riya'# string
s= True # boolean (T cannot be t. because of case sensitivity)
print(type(p))
print(type(q))
print(type(r))
print(type(s))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# for mathematical operations
x=1
y=2

print("add=",x+y)
print("sub=",y-x)
print("mul=",x*y)
print("div=",y/x)
print("exp=",y**x)

a=x+y
s=y-x
m=x*y
d=y/x
e=y**x
print(a,s,m,d,e, sep="\n")
# Out:
# add= 3
# sub= 1
# mul= 2
# div= 2.0
# exp= 2
# 3
# 1
# 2
# 2.0
# 2

# %%
#accepting the values of x and y from the user
x=int(input("enter the value of x:"))
y=int(input("enter the value of y:"))
#printing the values of x and y
print("x=",x)
print("y=",y)
#applying mathematical operations
print("add=",x+y)
print("sub=",y-x)
print("mul=",x*y)
print("div=",y/x)
print("exp=",y**x)
# Out:
# enter the value of x:2
# enter the value of y:8
# x= 2
# y= 8
# add= 10
# sub= 6
# mul= 16
# div= 4.0
# exp= 64

# %%
#generalised formula for the area of a circle
import math #to import the value of pi from the math library
r=float(input("enter the radius of the circle:"))
p= math.pi # the value of pi is assigned to "p". so we can now use the value of pi in the code
area=p*r*r
print("the area of the circle is",area)
# Out:
# enter the radius of the circle:1
# the area of the circle is 3.141592653589793

# %%
#finding the value of logx
import math
x=float(input("enter the value of x:"))
y=math.log10(x)
print("the value of log is",y)
# Out:
# enter the value of x:2
# the value of log is 0.3010299956639812

# %%
#checking which number is greater
x=int(input("enter the value of x:"))
y=int(input("enter the value of y:"))
if x>y:
    print("x is greater than y")
else:
    print("y is greater than x")
# Out:
# enter the value of x:7
# enter the value of y:4
# x is greater than y
